# %%
import pandas as pd

data = {
    "study_hours": [2,3,4,5,6,7,8,9,1,10],
    "attendance": [60,65,70,75,80,85,90,95,50,98],
    "marks": [35,40,45,50,55,60,65,70,30,78]
}

df = pd.DataFrame(data)
df.to_csv("/content/student_performance.csv", index=False)

print("CSV FILE CREATED SUCCESSFULLY")
# Out:
# CSV FILE CREATED SUCCESSFULLY

# %%
import pandas as pd

df = pd.read_csv("/content/student_performance.csv")
df
# Out:
#    study_hours  attendance  marks
# 0            2          60     35
# 1            3          65     40
# 2            4          70     45
# 3            5          75     50
# 4            6          80     55
# 5            7          85     60
# 6            8          90     65
# 7            9          95     70
# 8            1          50     30
# 9           10          98     78

# %%
df
# Out:
#    study_hours  attendance  marks
# 0            2          60     35
# 1            3          65     40
# 2            4          70     45
# 3            5          75     50
# 4            6          80     55
# 5            7          85     60
# 6            8          90     65
# 7            9          95     70
# 8            1          50     30
# 9           10          98     78

# %%
df.head()
# Out:
#    study_hours  attendance  marks
# 0            2          60     35
# 1            3          65     40
# 2            4          70     45
# 3            5          75     50
# 4            6          80     55

# %%
df.columns
# Out:
# Index(['study_hours', 'attendance', 'marks'], dtype='object')

# %%
df.describe()
# Out:
#        study_hours  attendance      marks
# count     10.00000   10.000000  10.000000
# mean       5.50000   76.800000  52.800000
# std        3.02765   15.711284  15.654605
# min        1.00000   50.000000  30.000000
# 25%        3.25000   66.250000  41.250000
# 50%        5.50000   77.500000  52.500000
# 75%        7.75000   88.750000  63.750000
# max       10.00000   98.000000  78.000000

# %%
import matplotlib.pyplot as plt

plt.scatter(df['study_hours'], df['marks'])
plt.xlabel('Study Hours')
plt.ylabel('Marks')
plt.title('Study Hours vs Marks')
plt.show()

# %% [markdown]
# Conclusion:
# Students who study more hours generally score higher marks.
# Attendance also affects performance positively.
